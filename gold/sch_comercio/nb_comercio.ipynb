# %%
dfc = spark.table("silver_desa.sch_silver_tb.clientes")
dfc.display()

# %%
dfv = spark.table("silver_desa.sch_silver_tb.ventas")
dfv.display()

# %%
dfjoin = dfc.join(dfv, dfc.id_cliente == dfv.cantidad, "inner")
display(dfjoin)

# %%
dfjoin.write.mode('overwrite').saveAsTable('gold_desa.sch_comercio_tb.reporte')
